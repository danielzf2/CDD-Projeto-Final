# %% [markdown]
# #                     Projeto Final CDD- Prever a nota de um filme no IDB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats import norm, probplot
import statsmodels.api as sm
from mpl_toolkits.mplot3d import Axes3D
import json

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)

# %%
### Função utilitária para fazer a regressão com constante adicionada
def regress(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

# %%
dados_filmes= pd.read_csv("tmdb_5000_movies.csv")

# %%
dados_filmes.drop(dados_filmes[dados_filmes["budget"]==0].index,inplace=True)

# %% [markdown]
# # Começaremos analisando os dados do Dataset
#
# ## As variáveis numéricas que analisaremos, para ver se há uma relação com a nota do filme, será as numéricas. Estas serão:
#
# ### title, runtime budget, revenue, popularity, vote_average, vote_count

# %% [markdown]
# ## Construindo o Dataframe

# %%
dados_novos = dados_filmes[["title","runtime","budget","revenue", "vote_average", "vote_count", "popularity","genres",'release_date']].copy()

# %% [markdown]
# #### Criação de colunas com o nome dos generos, sendo 1 para quando o filme é daquela categoria e 0 para quando não é , isso foi feito para tirar a coluna genre

# %%
genres = set()
for x in dados_novos['genres']:
    for g in json.loads(x):
        genres.add(g["name"])

genres
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western'}

# %% [markdown]
# #### Criacão do novo dataframe incluindo as novas colunas de gênero

# %%
def extrai_generos(item):
    generos = {'c_' + x: 0 for x in ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 
                              'Documentary', 'Drama', 'Family', 'Fantasy', 'Foreign', 
                              'History', 'Horror', 'Music', 'Mystery', 'Romance', 
                              'Science Fiction', 'TV Movie', 'Thriller', 'War', 'Western']}
    for g in json.loads(item):
        generos['c_' + g['name']] += 1
    return generos

dados_novos_teste = pd.DataFrame(list(dados_novos['genres'].apply(extrai_generos).values))

dados_novos_junto = dados_novos.join(dados_novos_teste)

dados_novos_junto.set_index("title",inplace=True)

# %%
dados_novos_junto.drop(columns= "genres", inplace=True)


dados_novos_junto
# Out:
#                                              runtime     budget     revenue  \
# title
# Avatar                                         162.0  237000000  2787965087
# Pirates of the Caribbean: At World's End       169.0  300000000   961000000
# Spectre                                        148.0  245000000   880674609
# The Dark Knight Rises                          165.0  250000000  1084939099
# John Carter                                    132.0  260000000   284139100
# Spider-Man 3                                   139.0  258000000   890871626
# Tangled                                        100.0  260000000   591794936
# Avengers: Age of Ultron                        141.0  280000000  1405403694
# Harry Potter and the Half-Blood Prince         153.0  250000000   933959197
# Batman v Superman: Dawn of Justice             151.0  250000000   873260194
# Superman Returns                               154.0  270000000   391081192
# Quantum of Solace                              106.0  200000000   586090727
# Pirates of the Caribbean: Dead Man's Chest     151.0  200000000  1065659812
# The Lone Ranger                                149.0  255000000    89289910
# Man of Steel                                   143.0  225000000   662845518
# The Chronicles of Narnia: Prince Caspian       150.0  225000000   419651413
# The Avengers                                   143.0  220000000  1519557910
# Pirates of the Caribbean: On Stranger Tides    136.0  380000000  1045713802
# Men in Black 3                                 106.0  225000000   624026776
# The Hobbit: The Battle of the Five Armies      144.0  250000000   956019788
# The Amazing Spider-Man                         136.0  215000000   752215857
# Robin Hood                                     140.0  200000000   310669540
# The Hobbit: The Desolation of Smaug            161.0  250000000   958400000
# The Golden Compass                             113.0  180000000   372234864
# King Kong                                      187.0  207000000   550000000
# Titanic                                        194.0  200000000  1845034188
# Captain America: Civil War                     147.0  250000000  1153304495
# Battleship                                     131.0  209000000   303025485
# Jurassic World                                 124.0  150000000  1513528810
# Skyfall                                        143.0  200000000  1108561013
# ...                                              ...        ...         ...
# A Dog's Breakfast                               88.0     120000           0
# The Married Woman                               95.0     120000           0
# The Birth of a Nation                          120.0    8500000    15861566
# Facing the Giants                              111.0     100000    10178331
# The Gallows                                     87.0     100000    42664410
# Eraserhead                                      89.0      10000     7000000
# The Past Is a Grotesque Animal                  77.0        100           0
# Pi                                              84.0      60000     3221152
# Queen Crab                                      90.0      75000           0
# Super Size Me                                  100.0      65000    28575078
# The Brain That Wouldn't Die                     82.0      62000           0
# Absentia                                        92.0      70000           0
# Tiny Furniture                                  99.0      65000      416498
# Hayride                                         93.0      60000           0
# Counting                                       111.0      50000           0
# The Call of Cthulhu                             47.0      50000           0
# The Signal                                      95.0    4000000      600896
# The Image Revolution                            81.0      50000           0
# Run, Hide, Die                                  75.0      50000           0
# Mutual Appreciation                            109.0     500000           0
# Down Terrace                                    89.0      31192       10000
# Clerks                                          92.0      27000     3151130
# Pink Narcissus                                  64.0      27000           0
# Dry Spell                                       90.0      22000           0
# Pink Flamingos                                  93.0      12000     6000000
# Tin Can Man                                     84.0         13           0
# Cure                                           111.0      20000       99000
# Primer                                          77.0       7000      424760
# El Mariachi                                     81.0     220000     2040920
# Newlyweds                                       85.0       9000           0
#
#                                              vote_average  vote_count  \
# title
# Avatar                                                7.2       11800
# Pirates of the Caribbean: At World's End              6.9        4500
# Spectre                                               6.3        4466
# The Dark Knight Rises                                 7.6        9106
# John Carter                                           6.1        2124
# Spider-Man 3                                          5.9        3576
# Tangled                                               7.4        3330
# Avengers: Age of Ultron                               7.3        6767
# Harry Potter and the Half-Blood Prince                7.4        5293
# Batman v Superman: Dawn of Justice                    5.7        7004
# Superman Returns                                      5.4        1400
# Quantum of Solace                                     6.1        2965
# Pirates of the Caribbean: Dead Man's Chest            7.0        5246
# The Lone Ranger                                       5.9        2311
# Man of Steel                                          6.5        6359
# The Chronicles of Narnia: Prince Caspian              6.3        1630
# The Avengers                                          7.4       11776
# Pirates of the Caribbean: On Stranger Tides           6.4        4948
# Men in Black 3                                        6.2        4160
# The Hobbit: The Battle of the Five Armies             7.1        4760
# The Amazing Spider-Man                                6.5        6586
# Robin Hood                                            6.2        1398
# The Hobbit: The Desolation of Smaug                   7.6        4524
# The Golden Compass                                    5.8        1303
# King Kong                                             6.6        2337
# Titanic                                               7.5        7562
# Captain America: Civil War                            7.1        7241
# Battleship                                            5.5        2114
# Jurassic World                                        6.5        8662
# Skyfall                                               6.9        7604
# ...                                                   ...         ...
# A Dog's Breakfast                                     5.9          24
# The Married Woman                                     7.1          20
# The Birth of a Nation                                 6.5         178
# Facing the Giants                                     6.6          64
# The Gallows                                           4.9         361
# Eraserhead                                            7.5         485
# The Past Is a Grotesque Animal                        5.5           2
# Pi                                                    7.1         586
# Queen Crab                                            3.3           3
# Super Size Me                                         6.6         506
# The Brain That Wouldn't Die                           4.4          32
# Absentia                                              5.8         121
# Tiny Furniture                                        5.6          59
# Hayride                                               5.1           6
# Counting                                              8.3           3
# The Call of Cthulhu                                   6.9          41
# The Signal                                            5.8         631
# The Image Revolution                                  5.7           3
# Run, Hide, Die                                        3.5           2
# Mutual Appreciation                                   6.1           8
# Down Terrace                                          6.3          26
# Clerks                                                7.4         755
# Pink Narcissus                                        6.0           9
# Dry Spell                                             6.0           1
# Pink Flamingos                                        6.2         110
# Tin Can Man                                           2.0           1
# Cure                                                  7.4          63
# Primer                                                6.9         658
# El Mariachi                                           6.6         238
# Newlyweds                                             5.9           5
#
#                                              popularity release_date  \
# title
# Avatar                                       150.437577   2009-12-10
# Pirates of the Caribbean: At World's End     139.082615   2007-05-19
# Spectre                                      107.376788   2015-10-26
# The Dark Knight Rises                        112.312950   2012-07-16
# John Carter                                   43.926995   2012-03-07
# Spider-Man 3                                 115.699814   2007-05-01
# Tangled                                       48.681969   2010-11-24
# Avengers: Age of Ultron                      134.279229   2015-04-22
# Harry Potter and the Half-Blood Prince        98.885637   2009-07-07
# Batman v Superman: Dawn of Justice           155.790452   2016-03-23
# Superman Returns                              57.925623   2006-06-28
# Quantum of Solace                            107.928811   2008-10-30
# Pirates of the Caribbean: Dead Man's Chest   145.847379   2006-06-20
# The Lone Ranger                               49.046956   2013-07-03
# Man of Steel                                  99.398009   2013-06-12
# The Chronicles of Narnia: Prince Caspian      53.978602   2008-05-15
# The Avengers                                 144.448633   2012-04-25
# Pirates of the Caribbean: On Stranger Tides  135.413856   2011-05-14
# Men in Black 3                                52.035179   2012-05-23
# The Hobbit: The Battle of the Five Armies    120.965743   2014-12-10
# The Amazing Spider-Man                        89.866276   2012-06-27
# Robin Hood                                    37.668301   2010-05-12
# The Hobbit: The Desolation of Smaug           94.370564   2013-12-11
# The Golden Compass                            42.990906   2007-12-04
# King Kong                                     61.226010   2005-12-14
# Titanic                                      100.025899   1997-11-18
# Captain America: Civil War                   198.372395   2016-04-27
# Battleship                                    64.928382   2012-04-11
# Jurassic World                               418.708552   2015-06-09
# Skyfall                                       93.004993   2012-10-25
# ...                                                 ...          ...
# A Dog's Breakfast                              2.213889   2007-03-03
# The Married Woman                              1.112792   1964-12-04
# The Birth of a Nation                          9.452808   2016-09-09
# Facing the Giants                              4.563698   2006-09-29
# The Gallows                                   18.045782   2015-07-10
# Eraserhead                                    20.399578   1977-03-19
# The Past Is a Grotesque Animal                 0.394575   2014-06-15
# Pi                                            27.788067   1998-07-10
# Queen Crab                                     0.140989   2015-09-29
# Super Size Me                                 10.400603   2004-01-17
# The Brain That Wouldn't Die                    2.407048   1962-02-25
# Absentia                                       6.328665   2011-03-03
# Tiny Furniture                                 2.380332   2010-11-12
# Hayride                                        0.412342   2012-10-13
# Counting                                       0.293587   2015-02-09
# The Call of Cthulhu                            1.777148   2005-01-01
# The Signal                                    27.662696   2014-03-15
# The Image Revolution                           0.545620   2013-11-21
# Run, Hide, Die                                 0.595809   2015-09-01
# Mutual Appreciation                            0.123068   2005-03-01
# Down Terrace                                   1.330379   2009-09-01
# Clerks                                        19.748658   1994-09-13
# Pink Narcissus                                 0.027811   1971-01-01
# Dry Spell                                      0.048948   2013-02-14
# Pink Flamingos                                 4.553644   1972-03-12
# Tin Can Man                                    0.332679   2007-01-01
# Cure                                           0.212443   1997-11-06
# Primer                                        23.307949   2004-10-08
# El Mariachi                                   14.269792   1992-09-04
# Newlyweds                                      0.642552   2011-12-26
#
#                                              c_Action  c_Adventure  \
# title
# Avatar                                            1.0          1.0
# Pirates of the Caribbean: At World's End          1.0          1.0
# Spectre                                           1.0          1.0
# The Dark Knight Rises                             1.0          0.0
# John Carter                                       1.0          1.0
# Spider-Man 3                                      1.0          1.0
# Tangled                                           0.0          0.0
# Avengers: Age of Ultron                           1.0          1.0
# Harry Potter and the Half-Blood Prince            0.0          1.0
# Batman v Superman: Dawn of Justice                1.0          1.0
# Superman Returns                                  1.0          1.0
# Quantum of Solace                                 1.0          1.0
# Pirates of the Caribbean: Dead Man's Chest        1.0          1.0
# The Lone Ranger                                   1.0          1.0
# Man of Steel                                      1.0          1.0
# The Chronicles of Narnia: Prince Caspian          0.0          1.0
# The Avengers                                      1.0          1.0
# Pirates of the Caribbean: On Stranger Tides       1.0          1.0
# Men in Black 3                                    1.0          0.0
# The Hobbit: The Battle of the Five Armies         1.0          1.0
# The Amazing Spider-Man                            1.0          1.0
# Robin Hood                                        1.0          1.0
# The Hobbit: The Desolation of Smaug               0.0          1.0
# The Golden Compass                                0.0          1.0
# King Kong                                         1.0          1.0
# Titanic                                           0.0          0.0
# Captain America: Civil War                        1.0          1.0
# Battleship                                        1.0          1.0
# Jurassic World                                    1.0          1.0
# Skyfall                                           1.0          1.0
# ...                                               ...          ...
# A Dog's Breakfast                                 NaN          NaN
# The Married Woman                                 NaN          NaN
# The Birth of a Nation                             NaN          NaN
# Facing the Giants                                 NaN          NaN
# The Gallows                                       NaN          NaN
# Eraserhead                                        NaN          NaN
# The Past Is a Grotesque Animal                    NaN          NaN
# Pi                                                NaN          NaN
# Queen Crab                                        NaN          NaN
# Super Size Me                                     NaN          NaN
# The Brain That Wouldn't Die                       NaN          NaN
# Absentia                                          NaN          NaN
# Tiny Furniture                                    NaN          NaN
# Hayride                                           NaN          NaN
# Counting                                          NaN          NaN
# The Call of Cthulhu                               NaN          NaN
# The Signal                                        NaN          NaN
# The Image Revolution                              NaN          NaN
# Run, Hide, Die                                    NaN          NaN
# Mutual Appreciation                               NaN          NaN
# Down Terrace                                      NaN          NaN
# Clerks                                            NaN          NaN
# Pink Narcissus                                    NaN          NaN
# Dry Spell                                         NaN          NaN
# Pink Flamingos                                    NaN          NaN
# Tin Can Man                                       NaN          NaN
# Cure                                              NaN          NaN
# Primer                                            NaN          NaN
# El Mariachi                                       NaN          NaN
# Newlyweds                                         NaN          NaN
#
#                                              c_Animation    ...      \
# title                                                       ...
# Avatar                                               0.0    ...
# Pirates of the Caribbean: At World's End             0.0    ...
# Spectre                                              0.0    ...
# The Dark Knight Rises                                0.0    ...
# John Carter                                          0.0    ...
# Spider-Man 3                                         0.0    ...
# Tangled                                              1.0    ...
# Avengers: Age of Ultron                              0.0    ...
# Harry Potter and the Half-Blood Prince               0.0    ...
# Batman v Superman: Dawn of Justice                   0.0    ...
# Superman Returns                                     0.0    ...
# Quantum of Solace                                    0.0    ...
# Pirates of the Caribbean: Dead Man's Chest           0.0    ...
# The Lone Ranger                                      0.0    ...
# Man of Steel                                         0.0    ...
# The Chronicles of Narnia: Prince Caspian             0.0    ...
# The Avengers                                         0.0    ...
# Pirates of the Caribbean: On Stranger Tides          0.0    ...
# Men in Black 3                                       0.0    ...
# The Hobbit: The Battle of the Five Armies            0.0    ...
# The Amazing Spider-Man                               0.0    ...
# Robin Hood                                           0.0    ...
# The Hobbit: The Desolation of Smaug                  0.0    ...
# The Golden Compass                                   0.0    ...
# King Kong                                            0.0    ...
# Titanic                                              0.0    ...
# Captain America: Civil War                           0.0    ...
# Battleship                                           0.0    ...
# Jurassic World                                       0.0    ...
# Skyfall                                              0.0    ...
# ...                                                  ...    ...
# A Dog's Breakfast                                    NaN    ...
# The Married Woman                                    NaN    ...
# The Birth of a Nation                                NaN    ...
# Facing the Giants                                    NaN    ...
# The Gallows                                          NaN    ...
# Eraserhead                                           NaN    ...
# The Past Is a Grotesque Animal                       NaN    ...
# Pi                                                   NaN    ...
# Queen Crab                                           NaN    ...
# Super Size Me                                        NaN    ...
# The Brain That Wouldn't Die                          NaN    ...
# Absentia                                             NaN    ...
# Tiny Furniture                                       NaN    ...
# Hayride                                              NaN    ...
# Counting                                             NaN    ...
# The Call of Cthulhu                                  NaN    ...
# The Signal                                           NaN    ...
# The Image Revolution                                 NaN    ...
# Run, Hide, Die                                       NaN    ...
# Mutual Appreciation                                  NaN    ...
# Down Terrace                                         NaN    ...
# Clerks                                               NaN    ...
# Pink Narcissus                                       NaN    ...
# Dry Spell                                            NaN    ...
# Pink Flamingos                                       NaN    ...
# Tin Can Man                                          NaN    ...
# Cure                                                 NaN    ...
# Primer                                               NaN    ...
# El Mariachi                                          NaN    ...
# Newlyweds                                            NaN    ...
#
#                                              c_History  c_Horror  c_Music  \
# title
# Avatar                                             0.0       0.0      0.0
# Pirates of the Caribbean: At World's End           0.0       0.0      0.0
# Spectre                                            0.0       0.0      0.0
# The Dark Knight Rises                              0.0       0.0      0.0
# John Carter                                        0.0       0.0      0.0
# Spider-Man 3                                       0.0       0.0      0.0
# Tangled                                            0.0       0.0      0.0
# Avengers: Age of Ultron                            0.0       0.0      0.0
# Harry Potter and the Half-Blood Prince             0.0       0.0      0.0
# Batman v Superman: Dawn of Justice                 0.0       0.0      0.0
# Superman Returns                                   0.0       0.0      0.0
# Quantum of Solace                                  0.0       0.0      0.0
# Pirates of the Caribbean: Dead Man's Chest         0.0       0.0      0.0
# The Lone Ranger                                    0.0       0.0      0.0
# Man of Steel                                       0.0       0.0      0.0
# The Chronicles of Narnia: Prince Caspian           0.0       0.0      0.0
# The Avengers                                       0.0       0.0      0.0
# Pirates of the Caribbean: On Stranger Tides        0.0       0.0      0.0
# Men in Black 3                                     0.0       0.0      0.0
# The Hobbit: The Battle of the Five Armies          0.0       0.0      0.0
# The Amazing Spider-Man                             0.0       0.0      0.0
# Robin Hood                                         0.0       0.0      0.0
# The Hobbit: The Desolation of Smaug                0.0       0.0      0.0
# The Golden Compass                                 0.0       0.0      0.0
# King Kong                                          0.0       0.0      0.0
# Titanic                                            0.0       0.0      0.0
# Captain America: Civil War                         0.0       0.0      0.0
# Battleship                                         0.0       0.0      0.0
# Jurassic World                                     0.0       0.0      0.0
# Skyfall                                            0.0       0.0      0.0
# ...                                                ...       ...      ...
# A Dog's Breakfast                                  NaN       NaN      NaN
# The Married Woman                                  NaN       NaN      NaN
# The Birth of a Nation                              NaN       NaN      NaN
# Facing the Giants                                  NaN       NaN      NaN
# The Gallows                                        NaN       NaN      NaN
# Eraserhead                                         NaN       NaN      NaN
# The Past Is a Grotesque Animal                     NaN       NaN      NaN
# Pi                                                 NaN       NaN      NaN
# Queen Crab                                         NaN       NaN      NaN
# Super Size Me                                      NaN       NaN      NaN
# The Brain That Wouldn't Die                        NaN       NaN      NaN
# Absentia                                           NaN       NaN      NaN
# Tiny Furniture                                     NaN       NaN      NaN
# Hayride                                            NaN       NaN      NaN
# Counting                                           NaN       NaN      NaN
# The Call of Cthulhu                                NaN       NaN      NaN
# The Signal                                         NaN       NaN      NaN
# The Image Revolution                               NaN       NaN      NaN
# Run, Hide, Die                                     NaN       NaN      NaN
# Mutual Appreciation                                NaN       NaN      NaN
# Down Terrace                                       NaN       NaN      NaN
# Clerks                                             NaN       NaN      NaN
# Pink Narcissus                                     NaN       NaN      NaN
# Dry Spell                                          NaN       NaN      NaN
# Pink Flamingos                                     NaN       NaN      NaN
# Tin Can Man                                        NaN       NaN      NaN
# Cure                                               NaN       NaN      NaN
# Primer                                             NaN       NaN      NaN
# El Mariachi                                        NaN       NaN      NaN
# Newlyweds                                          NaN       NaN      NaN
#
#                                              c_Mystery  c_Romance  \
# title
# Avatar                                             0.0        0.0
# Pirates of the Caribbean: At World's End           0.0        0.0
# Spectre                                            0.0        0.0
# The Dark Knight Rises                              0.0        0.0
# John Carter                                        0.0        0.0
# Spider-Man 3                                       0.0        0.0
# Tangled                                            0.0        0.0
# Avengers: Age of Ultron                            0.0        0.0
# Harry Potter and the Half-Blood Prince             0.0        0.0
# Batman v Superman: Dawn of Justice                 0.0        0.0
# Superman Returns                                   0.0        0.0
# Quantum of Solace                                  0.0        0.0
# Pirates of the Caribbean: Dead Man's Chest         0.0        0.0
# The Lone Ranger                                    0.0        0.0
# Man of Steel                                       0.0        0.0
# The Chronicles of Narnia: Prince Caspian           0.0        0.0
# The Avengers                                       0.0        0.0
# Pirates of the Caribbean: On Stranger Tides        0.0        0.0
# Men in Black 3                                     0.0        0.0
# The Hobbit: The Battle of the Five Armies          0.0        0.0
# The Amazing Spider-Man                             0.0        0.0
# Robin Hood                                         0.0        0.0
# The Hobbit: The Desolation of Smaug                0.0        0.0
# The Golden Compass                                 0.0        0.0
# King Kong                                          0.0        0.0
# Titanic                                            0.0        1.0
# Captain America: Civil War                         0.0        0.0
# Battleship                                         0.0        0.0
# Jurassic World                                     0.0        0.0
# Skyfall                                            0.0        0.0
# ...                                                ...        ...
# A Dog's Breakfast                                  NaN        NaN
# The Married Woman                                  NaN        NaN
# The Birth of a Nation                              NaN        NaN
# Facing the Giants                                  NaN        NaN
# The Gallows                                        NaN        NaN
# Eraserhead                                         NaN        NaN
# The Past Is a Grotesque Animal                     NaN        NaN
# Pi                                                 NaN        NaN
# Queen Crab                                         NaN        NaN
# Super Size Me                                      NaN        NaN
# The Brain That Wouldn't Die                        NaN        NaN
# Absentia                                           NaN        NaN
# Tiny Furniture                                     NaN        NaN
# Hayride                                            NaN        NaN
# Counting                                           NaN        NaN
# The Call of Cthulhu                                NaN        NaN
# The Signal                                         NaN        NaN
# The Image Revolution                               NaN        NaN
# Run, Hide, Die                                     NaN        NaN
# Mutual Appreciation                                NaN        NaN
# Down Terrace                                       NaN        NaN
# Clerks                                             NaN        NaN
# Pink Narcissus                                     NaN        NaN
# Dry Spell                                          NaN        NaN
# Pink Flamingos                                     NaN        NaN
# Tin Can Man                                        NaN        NaN
# Cure                                               NaN        NaN
# Primer                                             NaN        NaN
# El Mariachi                                        NaN        NaN
# Newlyweds                                          NaN        NaN
#
#                                              c_Science Fiction  c_TV Movie  \
# title
# Avatar                                                     1.0         0.0
# Pirates of the Caribbean: At World's End                   0.0         0.0
# Spectre                                                    0.0         0.0
# The Dark Knight Rises                                      0.0         0.0
# John Carter                                                1.0         0.0
# Spider-Man 3                                               0.0         0.0
# Tangled                                                    0.0         0.0
# Avengers: Age of Ultron                                    1.0         0.0
# Harry Potter and the Half-Blood Prince                     0.0         0.0
# Batman v Superman: Dawn of Justice                         0.0         0.0
# Superman Returns                                           1.0         0.0
# Quantum of Solace                                          0.0         0.0
# Pirates of the Caribbean: Dead Man's Chest                 0.0         0.0
# The Lone Ranger                                            0.0         0.0
# Man of Steel                                               1.0         0.0
# The Chronicles of Narnia: Prince Caspian                   0.0         0.0
# The Avengers                                               1.0         0.0
# Pirates of the Caribbean: On Stranger Tides                0.0         0.0
# Men in Black 3                                             1.0         0.0
# The Hobbit: The Battle of the Five Armies                  0.0         0.0
# The Amazing Spider-Man                                     0.0         0.0
# Robin Hood                                                 0.0         0.0
# The Hobbit: The Desolation of Smaug                        0.0         0.0
# The Golden Compass                                         0.0         0.0
# King Kong                                                  0.0         0.0
# Titanic                                                    0.0         0.0
# Captain America: Civil War                                 1.0         0.0
# Battleship                                                 1.0         0.0
# Jurassic World                                             1.0         0.0
# Skyfall                                                    0.0         0.0
# ...                                                        ...         ...
# A Dog's Breakfast                                          NaN         NaN
# The Married Woman                                          NaN         NaN
# The Birth of a Nation                                      NaN         NaN
# Facing the Giants                                          NaN         NaN
# The Gallows                                                NaN         NaN
# Eraserhead                                                 NaN         NaN
# The Past Is a Grotesque Animal                             NaN         NaN
# Pi                                                         NaN         NaN
# Queen Crab                                                 NaN         NaN
# Super Size Me                                              NaN         NaN
# The Brain That Wouldn't Die                                NaN         NaN
# Absentia                                                   NaN         NaN
# Tiny Furniture                                             NaN         NaN
# Hayride                                                    NaN         NaN
# Counting                                                   NaN         NaN
# The Call of Cthulhu                                        NaN         NaN
# The Signal                                                 NaN         NaN
# The Image Revolution                                       NaN         NaN
# Run, Hide, Die                                             NaN         NaN
# Mutual Appreciation                                        NaN         NaN
# Down Terrace                                               NaN         NaN
# Clerks                                                     NaN         NaN
# Pink Narcissus                                             NaN         NaN
# Dry Spell                                                  NaN         NaN
# Pink Flamingos                                             NaN         NaN
# Tin Can Man                                                NaN         NaN
# Cure                                                       NaN         NaN
# Primer                                                     NaN         NaN
# El Mariachi                                                NaN         NaN
# Newlyweds                                                  NaN         NaN
#
#                                              c_Thriller  c_War  c_Western
# title
# Avatar                                              0.0    0.0        0.0
# Pirates of the Caribbean: At World's End            0.0    0.0        0.0
# Spectre                                             0.0    0.0        0.0
# The Dark Knight Rises                               1.0    0.0        0.0
# John Carter                                         0.0    0.0        0.0
# Spider-Man 3                                        0.0    0.0        0.0
# Tangled                                             0.0    0.0        0.0
# Avengers: Age of Ultron                             0.0    0.0        0.0
# Harry Potter and the Half-Blood Prince              0.0    0.0        0.0
# Batman v Superman: Dawn of Justice                  0.0    0.0        0.0
# Superman Returns                                    0.0    0.0        0.0
# Quantum of Solace                                   1.0    0.0        0.0
# Pirates of the Caribbean: Dead Man's Chest          0.0    0.0        0.0
# The Lone Ranger                                     0.0    0.0        1.0
# Man of Steel                                        0.0    0.0        0.0
# The Chronicles of Narnia: Prince Caspian            0.0    0.0        0.0
# The Avengers                                        0.0    0.0        0.0
# Pirates of the Caribbean: On Stranger Tides         0.0    0.0        0.0
# Men in Black 3                                      0.0    0.0        0.0
# The Hobbit: The Battle of the Five Armies           0.0    0.0        0.0
# The Amazing Spider-Man                              0.0    0.0        0.0
# Robin Hood                                          0.0    0.0        0.0
# The Hobbit: The Desolation of Smaug                 0.0    0.0        0.0
# The Golden Compass                                  0.0    0.0        0.0
# King Kong                                           0.0    0.0        0.0
# Titanic                                             1.0    0.0        0.0
# Captain America: Civil War                          0.0    0.0        0.0
# Battleship                                          1.0    0.0        0.0
# Jurassic World                                      1.0    0.0        0.0
# Skyfall                                             1.0    0.0        0.0
# ...                                                 ...    ...        ...
# A Dog's Breakfast                                   NaN    NaN        NaN
# The Married Woman                                   NaN    NaN        NaN
# The Birth of a Nation                               NaN    NaN        NaN
# Facing the Giants                                   NaN    NaN        NaN
# The Gallows                                         NaN    NaN        NaN
# Eraserhead                                          NaN    NaN        NaN
# The Past Is a Grotesque Animal                      NaN    NaN        NaN
# Pi                                                  NaN    NaN        NaN
# Queen Crab                                          NaN    NaN        NaN
# Super Size Me                                       NaN    NaN        NaN
# The Brain That Wouldn't Die                         NaN    NaN        NaN
# Absentia                                            NaN    NaN        NaN
# Tiny Furniture                                      NaN    NaN        NaN
# Hayride                                             NaN    NaN        NaN
# Counting                                            NaN    NaN        NaN
# The Call of Cthulhu                                 NaN    NaN        NaN
# The Signal                                          NaN    NaN        NaN
# The Image Revolution                                NaN    NaN        NaN
# Run, Hide, Die                                      NaN    NaN        NaN
# Mutual Appreciation                                 NaN    NaN        NaN
# Down Terrace                                        NaN    NaN        NaN
# Clerks                                              NaN    NaN        NaN
# Pink Narcissus                                      NaN    NaN        NaN
# Dry Spell                                           NaN    NaN        NaN
# Pink Flamingos                                      NaN    NaN        NaN
# Tin Can Man                                         NaN    NaN        NaN
# Cure                                                NaN    NaN        NaN
# Primer                                              NaN    NaN        NaN
# El Mariachi                                         NaN    NaN        NaN
# Newlyweds                                           NaN    NaN        NaN
#
# [3766 rows x 27 columns]

# %% [markdown]
# #### Criação de novas colunas que contém o mês, ano, e dia , cada uma em sua própia coluna no dataframe

# %%
dados_novos_junto['ano'] , dados_novos_junto['mes'] , dados_novos_junto['dia'] = dados_novos_junto['release_date'].str.split('-',2).str
dados_novos_junto['ano'] = pd.to_numeric(dados_novos_junto['ano'])
dados_novos_junto['mes'] = pd.to_numeric(dados_novos_junto['mes'])
dados_novos_junto['dia']  = pd.to_numeric(dados_novos_junto['dia'] )

# %% [markdown]
# ## Variáveis para a análise

# %% [markdown]
# **Dicionário de dados:**
#
#
# Variável | Descrição
# :---:|---:
# title | Título do filme
# runtime | Tempo de filme
# budget | Orçamento
# revenue | Receita
# vote_average | Média dos votos
# vote_count | Número de votos das pessoas
# popularity | Popularidade
# genres | Os diferentes gêneros de filme
# c_Action | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Adventure | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Animation | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Comedy | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Crime | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Documentary | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Drama | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Family | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Fantasy | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Foreign | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_History | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Horror | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Music | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Mystery | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Romance | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Science Fiction | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_TV Movie | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Thriller | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_War | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# c_Western | 0 quando o filme não pertence à esse gênero, e 1 quando pertence
# ano | ano em que o filme foi lançado
# mês | mês em que o filme foi lançado
# dia | dia em que o filme foi lançado

# %% [markdown]
# ## Com a ajuda do comando Describe, poderemos analisar fatores importantes do Dataframe

# %%
dados_novos_junto.describe()
# Out:
#            runtime        budget       revenue  vote_average    vote_count  \
# count  3764.000000  3.766000e+03  3.766000e+03   3766.000000   3766.000000
# mean    109.324389  3.704284e+07  1.039547e+08      6.226474    856.496814
# std      20.753408  4.264651e+07  1.776399e+08      0.966228   1344.785690
# min       0.000000  1.000000e+00  0.000000e+00      0.000000      0.000000
# 25%      95.000000  8.000000e+06  6.009736e+06      5.700000    114.000000
# 50%     105.500000  2.300000e+07  3.883137e+07      6.300000    365.500000
# 75%     120.000000  5.000000e+07  1.220873e+08      6.900000    969.250000
# max     338.000000  3.800000e+08  2.787965e+09     10.000000  13752.000000
#
#         popularity     c_Action  c_Adventure  c_Animation     c_Comedy  \
# count  3766.000000  3221.000000  3221.000000  3221.000000  3221.000000
# mean     25.984641     0.282521     0.208010     0.060540     0.350512
# std      34.438253     0.450295     0.405947     0.238522     0.477204
# min       0.001586     0.000000     0.000000     0.000000     0.000000
# 25%       7.974990     0.000000     0.000000     0.000000     0.000000
# 50%      17.604955     0.000000     0.000000     0.000000     0.000000
# 75%      33.925801     1.000000     0.000000     0.000000     1.000000
# max     875.581305     1.000000     1.000000     1.000000     1.000000
#
#           ...         c_Mystery    c_Romance  c_Science Fiction   c_TV Movie  \
# count     ...       3221.000000  3221.000000        3221.000000  3221.000000
# mean      ...          0.074201     0.174170           0.127600     0.000931
# std       ...          0.262138     0.379314           0.333696     0.030509
# min       ...          0.000000     0.000000           0.000000     0.000000
# 25%       ...          0.000000     0.000000           0.000000     0.000000
# 50%       ...          0.000000     0.000000           0.000000     0.000000
# 75%       ...          0.000000     0.000000           0.000000     0.000000
# max       ...          1.000000     1.000000           1.000000     1.000000
#
#         c_Thriller        c_War    c_Western          ano          mes  \
# count  3221.000000  3221.000000  3221.000000  3766.000000  3766.000000
# mean      0.289662     0.035082     0.017075  2002.090813     6.935741
# std       0.453676     0.184016     0.129573    12.876561     3.393160
# min       0.000000     0.000000     0.000000  1916.000000     1.000000
# 25%       0.000000     0.000000     0.000000  1999.000000     4.000000
# 50%       0.000000     0.000000     0.000000  2005.000000     7.000000
# 75%       1.000000     0.000000     0.000000  2011.000000    10.000000
# max       1.000000     1.000000     1.000000  2016.000000    12.000000
#
#                dia
# count  3766.000000
# mean     15.433617
# std       8.520344
# min       1.000000
# 25%       9.000000
# 50%      15.000000
# 75%      22.000000
# max      31.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# ### Tirando os dados Nan

# %%
df = dados_novos_junto

df = df.dropna()

# %% [markdown]
# ### Verificando valores nulos das variáveis em certa coluna

# %%
np.sum(df.isnull())
# Out:
# runtime              0
# budget               0
# revenue              0
# vote_average         0
# vote_count           0
# popularity           0
# release_date         0
# c_Action             0
# c_Adventure          0
# c_Animation          0
# c_Comedy             0
# c_Crime              0
# c_Documentary        0
# c_Drama              0
# c_Family             0
# c_Fantasy            0
# c_Foreign            0
# c_History            0
# c_Horror             0
# c_Music              0
# c_Mystery            0
# c_Romance            0
# c_Science Fiction    0
# c_TV Movie           0
# c_Thriller           0
# c_War                0
# c_Western            0
# ano                  0
# mes                  0
# dia                  0
# dtype: int64

# %% [markdown]
# ## Separação das  variáveis

# %%
Y = df[ "vote_average"]

# %%
X = df[["runtime","budget","revenue","vote_count", "popularity","c_Action", "c_Adventure","c_Animation","c_Comedy","c_History",
        "c_Horror","c_Music","c_Mystery","c_Romance","c_Science Fiction","c_TV Movie","c_Thriller","c_War","c_Western","mes","ano"]]

# %% [markdown]
# ## Uso da função Regress

# %%
results = regress(X,Y)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           vote_average   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.374
# Method:                 Least Squares   F-statistic:                     92.47
# Date:                Mon, 12 Nov 2018   Prob (F-statistic):          7.39e-310
# Time:                        16:55:29   Log-Likelihood:                -3351.2
# No. Observations:                3220   AIC:                             6746.
# Df Residuals:                    3198   BIC:                             6880.
# Df Model:                          21
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                20.6025      2.595      7.941      0.000      15.515      25.690
# runtime               0.0144      0.001     22.121      0.000       0.013       0.016
# budget            -6.176e-09   4.31e-10    -14.343      0.000   -7.02e-09   -5.33e-09
# revenue           -2.854e-11   1.19e-10     -0.239      0.811   -2.62e-10    2.05e-10
# vote_count            0.0003   1.62e-05     17.857      0.000       0.000       0.000
# popularity            0.0012      0.001      2.391      0.017       0.000       0.002
# c_Action             -0.0122      0.033     -0.373      0.709      -0.076       0.052
# c_Adventure          -0.0941      0.035     -2.683      0.007      -0.163      -0.025
# c_Animation           0.2337      0.055      4.257      0.000       0.126       0.341
# c_Comedy             -0.0100      0.029     -0.348      0.728      -0.067       0.047
# c_History            -0.1067      0.064     -1.664      0.096      -0.232       0.019
# c_Horror              0.0420      0.042      0.996      0.319      -0.041       0.125
# c_Music              -0.0681      0.067     -1.011      0.312      -0.200       0.064
# c_Mystery            -0.0486      0.049     -0.995      0.320      -0.144       0.047
# c_Romance            -0.0136      0.034     -0.397      0.692      -0.081       0.054
# c_Science Fiction     0.0112      0.039      0.288      0.773      -0.065       0.087
# c_TV Movie            0.3787      0.398      0.951      0.342      -0.402       1.159
# c_Thriller           -0.0274      0.032     -0.855      0.393      -0.090       0.035
# c_War                -0.0697      0.071     -0.980      0.327      -0.209       0.070
# c_Western             0.0215      0.095      0.226      0.822      -0.165       0.208
# mes                   0.0213      0.004      5.883      0.000       0.014       0.028
# ano                  -0.0080      0.001     -6.252      0.000      -0.011      -0.006
# ==============================================================================
# Omnibus:                      276.787   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              464.042
# Skew:                          -0.625   Prob(JB):                    1.72e-101
# Kurtosis:                       4.376   Cond. No.                     4.87e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.87e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Adotamos um ALFA de 5%, então tiramos os valores que tem um P>T maior que o ALFA

# %%
X = df[["runtime","budget","revenue","vote_count", "popularity","mes","ano"]]

# %% [markdown]
# Separando o dataframe em teste e treinamento

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=RANDOM_SEED)

# %% [markdown]
# Treinando, criando , testando e calculando o modelo de regressão linear

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()       #cria
model.fit(X_train, y_train)        #treina 
y_pred = model.predict(X_test)      #testa 

1 - mean_squared_error(y_test, y_pred) / np.var(y_test)
# Out:
# 0.38747462761081053

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

model = RandomForestRegressor()       #cria
model.fit(X_train, y_train)        #treina 
y_pred = model.predict(X_test)      #testa 

1 - mean_squared_error(y_test, y_pred) / np.var(y_test)
# Out:
# 0.45583843342651187
