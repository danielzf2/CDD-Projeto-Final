# %% [markdown]
# #                     Projeto Final CDD- Prever a nota de um filme no IDB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats import norm, probplot
import statsmodels.api as sm
from mpl_toolkits.mplot3d import Axes3D

# %%
### Função utilitária para fazer a regressão com constante adicionada
def regress(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

# %%
dados_filmes= pd.read_csv("tmdb_5000_movies.csv")

dados_filmes
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %% [markdown]
# # Começaremos analisando os dados do Dataset
#
# ## As variáveis numéricas que analisaremos, para ver se há uma relação com a nota do filme, será as numéricas. Estas serão:
#
# ### title, runtime budget, revenue, popularity, vote_average, vote_count

# %% [markdown]
# ## Construindo o Dataframe

# %%
dados_novos = dados_filmes[["title","runtime","budget","revenue", "vote_average", "vote_count", "popularity"]].copy()

dados_novos = dados_novos.set_index("title")
dados_novos
# Out:
#                                              runtime     budget     revenue  \
# title
# Avatar                                         162.0  237000000  2787965087
# Pirates of the Caribbean: At World's End       169.0  300000000   961000000
# Spectre                                        148.0  245000000   880674609
# The Dark Knight Rises                          165.0  250000000  1084939099
# John Carter                                    132.0  260000000   284139100
# Spider-Man 3                                   139.0  258000000   890871626
# Tangled                                        100.0  260000000   591794936
# Avengers: Age of Ultron                        141.0  280000000  1405403694
# Harry Potter and the Half-Blood Prince         153.0  250000000   933959197
# Batman v Superman: Dawn of Justice             151.0  250000000   873260194
# Superman Returns                               154.0  270000000   391081192
# ...

# %% [markdown]
# ## Variáveis para a análise

# %% [markdown]
# **Dicionário de dados:**
#
#
# Variável | Descrição
# :---:|---:
# title | Título do filme
# runtime | Tempo de filme
# budget | Orçamento
# revenue | Receita
# vote_average | Média dos votos
# vote_count | Número de votos das pessoas
# popularity | Popularidade
# production_countries | País de produção

# %% [markdown]
# ## Com a ajuda do comando Describe, poderemos analisar fatores importantes do Dataframe

# %%
dados_novos.describe()
# Out:
#            runtime        budget       revenue  vote_average    vote_count  \
# count  4801.000000  4.803000e+03  4.803000e+03   4803.000000   4803.000000
# mean    106.875859  2.904504e+07  8.226064e+07      6.092172    690.217989
# std      22.611935  4.072239e+07  1.628571e+08      1.194612   1234.585891
# min       0.000000  0.000000e+00  0.000000e+00      0.000000      0.000000
# 25%      94.000000  7.900000e+05  0.000000e+00      5.600000     54.000000
# 50%     103.000000  1.500000e+07  1.917000e+07      6.200000    235.000000
# 75%     118.000000  4.000000e+07  9.291719e+07      6.800000    737.000000
# max     338.000000  3.800000e+08  2.787965e+09     10.000000  13752.000000
#
#         popularity
# count  4803.000000
# mean     21.492301
# std      31.816650
# min       0.000000
# 25%       4.668070
# 50%      12.921594
# 75%      28.313505
# max     875.581305

# %%
df = dados_novos[["title","runtime","budget","revenue", "vote_average", "vote_count", "popularity"]]

# %% [markdown]
# ### Verificando valores nulos das variáveis em certa coluna

# %%
np.sum(df.isnull())
# Out:
# title           0
# runtime         2
# budget          0
# revenue         0
# vote_average    0
# vote_count      0
# popularity      0
# dtype: int64

# %% [markdown]
# ### Tirando os dados Nan

# %%
df = df.dropna()

# %% [markdown]
# ## Separação das  variáveis

# %%
Y = df[ "vote_average"]

# %%
X = df[["runtime","budget","revenue","vote_count", "popularity"]]

# %% [markdown]
# ## Uso da função Regress

# %%
results = regress(X,Y)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           vote_average   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     266.8
# Date:                Tue, 06 Nov 2018   Prob (F-statistic):          2.28e-252
# Time:                        15:08:18   Log-Likelihood:                -7063.7
# No. Observations:                4801   AIC:                         1.414e+04
# Df Residuals:                    4795   BIC:                         1.418e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.1202      0.075     55.206      0.000       3.974       4.266
# ...

# %% [markdown]
# # adicionar lucro, lugar de producao do filme
